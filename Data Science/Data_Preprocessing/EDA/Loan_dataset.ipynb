# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
dataset = files.upload()
# Out:
#      <input type="file" id="files-7d4cadac-ca47-46e3-b048-f831050959db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d4cadac-ca47-46e3-b048-f831050959db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('loan_small.csv')

# %%
df
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
df.shape
# Out:
# (16, 7)

# %%
df.head()
# Out:
#     Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0  LP001002     NaN           5849.0                0.0         NaN  urban
# 1  LP001003    Male           4583.0                NaN       128.0   semi
# 2  LP001005    Male           3000.0                0.0        66.0    NaN
# 3  LP001006  Female           2583.0             2358.0       120.0   semi
# 4  LP001008    Male              NaN                0.0       141.0  urban
#
#   Loan_Status
# 0           Y
# 1           N
# 2           Y
# 3         NaN
# 4           Y

# %%
df.tail()
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 11  LP001027    Male           2500.0             1840.0       109.0  urban
# 12  LP001028  Female              NaN             8106.0         NaN  urban
# 13  LP001029    Male           1853.0             2840.0       114.0  urban
# 14  LP001030    Male           1299.0             1086.0        17.0   semi
# 15  LP001032    Male           4950.0                0.0       125.0   semi
#
#    Loan_Status
# 11           Y
# 12           Y
# 13           N
# 14           Y
# 15           Y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            16 non-null     object
#  1   Gender             15 non-null     object
#  2   ApplicantIncome    14 non-null     float64
#  3   CoapplicantIncome  15 non-null     float64
#  4   LoanAmount         13 non-null     float64
#  5   Area               15 non-null     object
#  6   Loan_Status        15 non-null     object
# dtypes: float64(3), object(4)
# memory usage: 1.0+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count        14.000000          15.000000   13.000000
# mean       4103.571429        2509.333333  140.923077
# std        2858.096481        3147.982090   86.032418
# min        1299.000000           0.000000   17.000000
# 25%        2520.750000         350.000000  109.000000
# 50%        3118.000000        1526.000000  125.000000
# 75%        4858.250000        2672.000000  158.000000
# max       12841.000000       10968.000000  349.000000

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# ##Missig Value

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               1
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 1
# Loan_Status          1
# dtype: int64

# %% [markdown]
# Here 'Loan_Status' is considered as target variable. so first we want clear missing values in target varibale by using function **'dropna()'**.
#
# > (If missing occur from target variables, then just drop the records)

# %%
data=df['Loan_Status'].dropna()

# %%
data
# Out:
# 0     Y
# 1     N
# 2     Y
# 4     Y
# 5     Y
# 6     Y
# 7     N
# 8     Y
# 9     N
# 10    Y
# 11    Y
# 12    Y
# 13    N
# 14    Y
# 15    Y
# Name: Loan_Status, dtype: object

# %%
df
# Out:
#      Loan_ID  Gender  ApplicantIncome  CoapplicantIncome  LoanAmount   Area  \
# 0   LP001002     NaN           5849.0                0.0         NaN  urban
# 1   LP001003    Male           4583.0                NaN       128.0   semi
# 2   LP001005    Male           3000.0                0.0        66.0    NaN
# 3   LP001006  Female           2583.0             2358.0       120.0   semi
# 4   LP001008    Male              NaN                0.0       141.0  urban
# 5   LP001011    Male           5417.0             4196.0       267.0   semi
# 6   LP001013    Male           2333.0             1516.0         NaN  rural
# 7   LP001014  Female           3036.0             2504.0       158.0   semi
# 8   LP001018    Male           4006.0             1526.0       168.0  rural
# 9   LP001020    Male          12841.0            10968.0       349.0   semi
# 10  LP001024  Female           3200.0              700.0        70.0  urban
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               1
# ApplicantIncome      2
# CoapplicantIncome    1
# LoanAmount           3
# Area                 1
# Loan_Status          1
# dtype: int64
